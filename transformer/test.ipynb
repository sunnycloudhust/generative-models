# %%
from preprocess import Preprocess
import torch
import numpy

# %%
batch_size = 100
d_embed = 128
d_model = 64
seq_len = 20
vocab_size = 1000

# %%
x = torch.rand(batch_size, seq_len, d_embed)
print(x.shape)
# Out:
# torch.Size([100, 20, 128])

# %%
position = torch.arange(0, seq_len).unsqueeze(0)
print(position.shape)
# Out:
# torch.Size([1, 20])

# %%
output = torch.zeros(batch_size, seq_len, d_embed)
div_term = torch.exp(torch.arange(0, d_embed, 2).float() * -(d_embed / d_embed))
