# %%
import torch
import torch.nn as nn

# %%
num_timesteps=1000
beta_start=0.0001
beta_end=0.02

# %%
a = torch.linspace(beta_start, beta_end, num_timesteps).reshape(10000)
a
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a = torch.linspace(beta_start, beta_end, num_timesteps).reshape(10000)
#       2 a
#
# RuntimeError: shape '[10000]' is invalid for input of size 1000
